# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# MPG: Millas por galón
# MSRP: Precio de venta

df = pd.read_csv("data.csv")
df.sample(10)
# Out:
#            Make    Model  Year                Engine Fuel Type  Engine HP  \
# 7814       Audi       Q5  2016     premium unleaded (required)      220.0
# 1240      Honda   Accord  2016                regular unleaded      185.0
# 9058   Chrysler  Sebring  2008        flex-fuel (unleaded/E85)      186.0
# 11825    Toyota    Yaris  2017                regular unleaded      106.0
# 4537       Ford    F-150  2016                regular unleaded      325.0
# 8875       Audi       S5  2016     premium unleaded (required)      333.0
# 229    Chrysler      300  2017                regular unleaded      292.0
# 4872        Kia    Forte  2016                regular unleaded      173.0
# 9075        Kia   Sedona  2015                regular unleaded      276.0
# 863        Saab      9-5  2009  premium unleaded (recommended)      260.0
#
#        Engine Cylinders Transmission Type      Driven_Wheels  Number of Doors  \
# ...

# %%
df.shape
# Out:
# (11914, 16)

# %%
# Correlación de Pearson
# -1 < r < 0

# Finding the relations between the variables.
plt.figure(figsize=(15,10))
c = df.corr()
sns.heatmap(c, cmap="BrBG",annot=True)
c

# %% [markdown]
# Correlación positiva --> (>0.5)
#
# Correlación negativa --> (<-0.45)

# %%
df.corr()
# Out:
#                       Year  Engine HP  Engine Cylinders  Number of Doors  \
# Year              1.000000   0.351794         -0.041479         0.263787
# Engine HP         0.351794   1.000000          0.779988        -0.102713
# Engine Cylinders -0.041479   0.779988          1.000000        -0.140088
# Number of Doors   0.263787  -0.102713         -0.140088         1.000000
# highway MPG       0.258240  -0.406563         -0.621606         0.118570
# city mpg          0.198171  -0.439371         -0.600776         0.120881
# Popularity        0.073049   0.037501          0.041145        -0.048272
# MSRP              0.227590   0.662008          0.531312        -0.126635
#
#                   highway MPG  city mpg  Popularity      MSRP
# Year                 0.258240  0.198171    0.073049  0.227590
# Engine HP           -0.406563 -0.439371    0.037501  0.662008
# Engine Cylinders    -0.621606 -0.600776    0.041145  0.531312
# Number of Doors      0.118570  0.120881   -0.048272 -0.126635
# ...

# %%
sns.heatmap(df.corr(), cmap="BrBG", annot=True)

# %% [markdown]
# ### Correlación de Pearson
# #### -1 < r < 0
# ![](correlation-examples.svg)

# %%
#Hay veces que existen correlaciones entre los datos pero que no tienen ningún tipo de valor
#Se trataría más de una casualidad
